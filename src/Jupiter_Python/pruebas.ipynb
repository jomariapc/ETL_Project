# %%
import pandas as pd
from PyPower.py import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Mjp\Documents\IronhackLocal\0-Projects\ETL_Project\src\pruebas.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Mjp/Documents/IronhackLocal/0-Projects/ETL_Project/src/pruebas.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mjp/Documents/IronhackLocal/0-Projects/ETL_Project/src/pruebas.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from PyPower.py import *
#
# ModuleNotFoundError: No module named 'PyPower'

# %% [markdown]
# ### CSV OTTER

# %%
otter = pd.read_csv('../data/0-raw/otter_all.csv')

otter.head()
# Out:
#    Unnamed: 0                Fecha        Marca                     Locación  \
# 0           0  2023-11-03 15:55:55  Umbrella SH     EMEA - SP - MAD - Tetuan
# 1           1  2023-11-03 15:49:40  Umbrella SH     EMEA - SP - MAD - Tetuan
# 2           2  2023-11-03 15:49:02  Umbrella SH     EMEA - SP - MAD - Tetuan
# 3           3  2023-11-03 15:48:41  Umbrella SH  Umbrella SH - Calle Linares
# 4           4  2023-11-03 15:44:25  Umbrella SH                       Goleta
#
#       Canal ID de la orden Estado de la orden Subtotal Impuesto Descuentos  \
# 0   justeat      138656463              Nuevo       10        0          0
# 1   justeat      138656912              Nuevo     22,4        0          0
# 2     glovo       MSDGW9UM          Entregado     10,4        0          0
# 3  ubereats          8D40B              Nuevo     36,6        0      -13,9
# 4  ubereats          DF131          Entregado     31,8        0      -13,9
#
#    Cargos por error en el pedido Código de moneda
# ...

# %%
otter.Impuesto.value_counts()
# Out:
# Impuesto
# 0       517
# 1,21      1
# 4,95      1
# 4,21      1
# 2,85      1
# 2,68      1
# 2,4       1
# 2,71      1
# 2,44      1
# 2,43      1
# 3,7       1
# 2,36      1
# 1,95      1
# 1,94      1
# 6,14      1
# 2,51      1
# 1,49      1
# 4,27      1
# Name: count, dtype: int64

# %%
otter.drop(columns='Unnamed: 0', 'Fecha', 'Marca', 'Locación', 'Canal', 'ID de la orden',
       'Estado de la orden', 'Subtotal', 'Impuesto', 'Descuentos',
       'Cargos por error en el pedido', 'Código de moneda'])

# %%
deliverect_just_eat = pd.read_csv('../data/0-raw/202310_deliverect.csv')

deliverect_just_eat.head()
# Out:
#                  PickupTime        PickupTimeUTC               CreatedTime  \
# 0  2023-10-31 22:46:15+0100  2023-10-31 21:46:15  2023-10-31 22:31:15+0100
# 1  2023-10-31 22:16:25+0100  2023-10-31 21:16:25  2023-10-31 22:02:26+0100
# 2  2023-10-29 21:34:14+0100  2023-10-29 20:34:14  2023-10-29 21:20:15+0100
# 3  2023-10-29 21:07:09+0100  2023-10-29 20:07:09  2023-10-29 20:53:10+0100
# 4  2023-10-29 20:42:17+0100  2023-10-29 19:42:17  2023-10-29 20:28:17+0100
#
#         CreatedTimeUTC  ScheduledTime  ScheduledTimeUTC  \
# 0  2023-10-31 21:31:15            NaN               NaN
# 1  2023-10-31 21:02:26            NaN               NaN
# 2  2023-10-29 20:20:15            NaN               NaN
# 3  2023-10-29 19:53:10            NaN               NaN
# 4  2023-10-29 19:28:17            NaN               NaN
#
#                                 Location    OrderID   Channel     Status  ...  \
# 0                       Alicante - Bazan  138509659  Just Eat   ACCEPTED  ...
# ...
